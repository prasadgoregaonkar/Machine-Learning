# %% [markdown]
# <a href="https://colab.research.google.com/github/prasadgoregaonkar/Machine-Learning/blob/main/EDA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("train-200907-141856.csv")

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.countplot(x='Survived',data=df)

# %%
sns.countplot(x='Survived',data=df,hue='Sex')

# %%
#LineChart
sns.lineplot(x='Age',y='Fare',data=df)

# %%
#ScatterPlot
df.plot.scatter('Age','Fare')

# %%
df.plot.scatter('Age','Survived')

# %%
#Histogram
df['Age'].hist(bins=40)

# %%
#pieChart
import matplotlib.pyplot as plt
sizes=df['Survived'].value_counts()
fig1,ax1=plt.subplots()
ax1.pie(sizes,labels=['Not Survived','Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
